# %%
import pandas as pd
import altair as alt
import altair_latimes as lat

# %%
alt.themes.register('latimes', lat.theme)
alt.themes.enable('latimes')
# Out:
# ThemeRegistry.enable('latimes')

# %% [markdown]
# ### Import

# %% [markdown]
# District data downloaded from portal

# %%
df = pd.read_csv("../data/raw/regional-conservation.csv", parse_dates=["month"])

# %%
df_monthly = df[df.month != "Cumulative"]

# %%
df_monthly["reporting_month"] = pd.to_datetime(df_monthly["year"].astype(str) + "-" +  df_monthly["month"].astype(str) + "-15" )
# Out:
# /var/folders/7p/v902smb50m50mm_swb_lj1rh0000gn/T/ipykernel_11880/2456071992.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_monthly["reporting_month"] = pd.to_datetime(df_monthly["year"].astype(str) + "-" +  df_monthly["month"].astype(str) + "-15" )

# %%
df_monthly
# Out:
#     hydrologic_region  month  water_use_baseline  supplier_count  \
# 0         Tulare Lake   July         17946202676              32
# 1      South Lahontan   July          5638495317              16
# 2         South Coast   July         99078328467             175
# 3   San Joaquin River   July         12491127226              29
# 4   San Francisco Bay   July         28465149969              47
# ..                ...    ...                 ...             ...
# 85   Sacramento River  March         10659783409              42
# 86     North Lahontan  March           235814594               5
# 87        North Coast  March          1025596111              14
# 88     Colorado River  March          3161110125              10
# 89      Central Coast  March          3082968194              27
#
#     water_use_current  total_population_served  year  pct_savings  \
# 0         17664043951                  1984217  2021    -0.015722
# ...

# %%
df_monthly[df_monthly.hydrologic_region=="South Coast"].tail(12)
# Out:
#    hydrologic_region      month  water_use_baseline  supplier_count  \
# 2        South Coast       July         99078328467             175
# 12       South Coast     August        102301312326             174
# 22       South Coast  September         95563514235             175
# 32       South Coast    October         91491453042             174
# 42       South Coast   November         75291047874             174
# 52       South Coast   December         74466039240             172
# 62       South Coast    January         60433815644             168
# 72       South Coast   February         63549785858             166
# 82       South Coast      March         56849921122             163
#
#     water_use_current  total_population_served  year  pct_savings  \
# 2         98840670775                 20331967  2021    -0.002399
# 12        99171660540                 20425059  2021    -0.030592
# 22        91539109543                 20431794  2021    -0.042112
# ...

# %%
alt.Chart(
    df_monthly[df_monthly.hydrologic_region=="South Coast"].tail(12)
).mark_bar().encode(
    x="reporting_month:O",
    y="pct_savings",
    color=alt.condition(
        alt.datum.pct_savings > 0,
        alt.value("#e6ae56"),  # The positive color
        alt.value("#83c6e0")  # The negative color
    )    
).properties(title="South Coast water savings", width=600)
# Out:
# alt.Chart(...)
