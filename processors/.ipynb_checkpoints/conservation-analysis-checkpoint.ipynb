# %%
import pandas as pd
import altair as alt
import altair_latimes as lat
from pandas.tseries.offsets import MonthEnd

# %%
alt.themes.register('latimes', lat.theme)
alt.themes.enable('latimes')
# Out:
# ThemeRegistry.enable('latimes')

# %%
pd.set_option('display.float_format', lambda x: '%.3f' % x)

# %% [markdown]
# ### Import

# %%
df = pd.read_csv("../data/raw/uw-usage.csv", parse_dates=["Reporting Month"])

# %%
baselines_df = pd.read_csv("../data/raw/uw-2020-baseline-values.csv")

# %% [markdown]
# ### Clean

# %% [markdown]
# Remove junk from column names

# %%
df.columns = df.columns.str.replace(" ","_").str.replace("-","_").str.replace(r'[#,@,&,(,)]', '', regex=True).str.lower()

# %% [markdown]
# Eliminate double spaces in supplier names

# %%
df.supplier_name = df.supplier_name.str.replace("  ", " ")

# %% [markdown]
# Clean up baselines column names as we did in the previous notebook

# %%
baselines_df.columns = baselines_df.columns.str.replace(" ","_").str.replace("-","_").str.replace(r'[#,@,&,(,)]', '', regex=True).str.lower()

# %%
baselines_df.supplier_name = baselines_df.supplier_name.str.replace("  ", " ")

# %%
baselines_trimmed_df = baselines_df[[
    'supplier_name', 
    'public_water_system_id', 
    'month', 
    #'original_units',
    # 'total_potable_production_original_units',
    # 'potable_commercial_agriculture_original_units',
    'total_potable_production_minus_ag_gallons', 
    # 'staff_notes'
]].copy()

# %% [markdown]
# Get rid of some unnecessary columns

# %%
trim_df = df[[
    'supplier_name', 
    'public_water_system_id', 
    'reporting_month', 
    'county',
    'hydrologic_region', 
    'climate_zone', 
    'total_population_served',
    'calculated_total_potable_water_production_gallons_ag_excluded',
    'calculated_r_gpcd', 
    # 'month'
]].copy()

# %% [markdown]
# ### Get populations by supplier, hydrologic region and state total

# %% [markdown]
# Using populations from the beginning of the drought emergency

# %%
pops_by_supplier = df[
    df.reporting_month == "2021-07-15"
][["supplier_name","hydrologic_region","total_population_served"]]

# %%
pops_by_region = pops_by_supplier.groupby(
    ["hydrologic_region"]
)["total_population_served"].sum().reset_index()

# %%
pop_state = pops_by_region.total_population_served.sum()
pop_state
# Out:
# 37110227

# %% [markdown]
# ### Merge

# %% [markdown]
# Filter df to July 2021 and later

# %%
filter_df = trim_df[
    (trim_df.reporting_month >= "2021-07-15")
].copy()

# %% [markdown]
# Remove -999999999

# %%
filter_df = filter_df[filter_df.calculated_total_potable_water_production_gallons_ag_excluded != -999999999]

# %% [markdown]
# Make a month column to merge with baselines

# %%
filter_df["month"] = filter_df["reporting_month"].dt.month

# %%
merge_df = pd.merge(
    filter_df, 
    baselines_trimmed_df, 
    how="left", 
    on=["supplier_name", "public_water_system_id", "month"]
).rename(
    columns={
        "calculated_total_potable_water_production_gallons_ag_excluded": "total_gallons_current",
        "total_potable_production_minus_ag_gallons": "total_gallons_baseline"
    }
).drop("month", axis=1)

# %% [markdown]
# ### Remove duplicates

# %%
tmp = merge_df.set_index(['supplier_name', 'reporting_month'])

# %%
merge_df = tmp[~tmp.index.duplicated()].reset_index()

# %% [markdown]
# ### Calculate percent changes by month

# %%
def pct_change(new, old):
    return (new - old) / old

# %% [markdown]
# By supplier

# %%
merge_df["gallons_pct_change"] = merge_df.apply(lambda x: pct_change(x.total_gallons_current, x.total_gallons_baseline), axis=1)

# %% [markdown]
# Filter out outliers

# %%
# lower_thresh=-0.5
# upper_thresh=1.3

# %%
# districts_filtered = merge_df[
#     (merge_df['gallons_pct_change']<upper_thresh)&(merge_df['gallons_pct_change']>lower_thresh)
# ]

# %% [markdown]
# By region

# %%
regions_df = merge_df.groupby(
    ["hydrologic_region", "reporting_month"]
)[["total_gallons_current","total_gallons_baseline", "supplier_name"]].agg({
    "total_gallons_current":"sum",
    "total_gallons_baseline":"sum",
    "supplier_name":"size"
}).reset_index()

# %%
regions_df["gallons_pct_change"] = regions_df.apply(lambda x: pct_change(x.total_gallons_current, x.total_gallons_baseline), axis=1)

# %% [markdown]
# Statewide

# %%
merge_df["state"] = "Statewide"

# %%
statewide_df = merge_df.groupby(["state", "reporting_month"])[["total_gallons_current","total_gallons_baseline"]].sum().reset_index()

# %%
statewide_df["gallons_pct_change"] = statewide_df.apply(lambda x: pct_change(x.total_gallons_current, x.total_gallons_baseline), axis=1)

# %% [markdown]
# ### Calculate cumulative savings since July 2021

# %% [markdown]
# Set up some vars and function

# %%
def month_diff(a, b):
    return 12 * (a.year - b.year) + (a.month - b.month)

# %%
def gallons_per_unit(gallons, baseline, population, time):
    return ((baseline - gallons) / population) / time

# %%
# voluntary_reductions_begin = pd.to_datetime('2021-07-08')
voluntary_reductions_begin = pd.to_datetime('2021-07-01')
voluntary_reductions_begin
# Out:
# Timestamp('2021-07-01 00:00:00')

# %%
latest_month = statewide_df[
    statewide_df.reporting_month == statewide_df.reporting_month.max()
].iloc[0]['reporting_month']

latest_month = pd.to_datetime(latest_month, format="%Y%m") + MonthEnd(0)

latest_month
# Out:
# Timestamp('2022-12-31 00:00:00')

# %%
months_since_reductions_begin = month_diff(latest_month, voluntary_reductions_begin)
months_since_reductions_begin
# Out:
# 17

# %%
days_since_reductions = (latest_month - voluntary_reductions_begin).days
days_since_reductions
# Out:
# 548

# %% [markdown]
# Get date of this monthly report

# %%
date = statewide_df[
    (statewide_df.reporting_month==statewide_df.reporting_month.max())
].iloc[0]["reporting_month"]

# %% [markdown]
# Drop suppliers with missing data

# %%
counts = merge_df.groupby("supplier_name")["reporting_month"].count().reset_index()

# %%
max_count = max(counts.reporting_month)
max_count
# Out:
# 18

# %%
suppliers_with_complete_data = list(counts[counts.reporting_month == max_count].supplier_name)

# %%
complete_data = merge_df[merge_df.supplier_name.isin(suppliers_with_complete_data)].copy()

# %%
#complete_data[complete_data.reporting_month == "2023-03-15"]

# %% [markdown]
# By district

# %%
district_cumulative_savings_df = complete_data.groupby(
    ["supplier_name","hydrologic_region"]
)[["total_gallons_current","total_gallons_baseline"]].sum().reset_index()

# %%
district_cumulative_savings_df = pd.merge(
    district_cumulative_savings_df,
    pops_by_supplier[["supplier_name","hydrologic_region","total_population_served"]],
    how="left",
    on=["supplier_name","hydrologic_region"]
)

# %%
district_cumulative_savings_df["cumulative_pct_change"] = district_cumulative_savings_df.apply(lambda x: pct_change(x.total_gallons_current, x.total_gallons_baseline), axis=1)

# %%
district_cumulative_savings_df['date'] = date

# %%
district_cumulative_savings_df['months_since'] = months_since_reductions_begin
district_cumulative_savings_df['days_since'] = days_since_reductions

# %%
district_cumulative_savings_df['gallons_saved_per_month'] = district_cumulative_savings_df.apply(
    lambda x: gallons_per_unit(
        x.total_gallons_current, x.total_gallons_baseline, x.total_population_served, x.months_since
    ), axis=1
)

# %%
district_cumulative_savings_df['gallons_saved_per_day'] = district_cumulative_savings_df.apply(
    lambda x: gallons_per_unit(
        x.total_gallons_current, x.total_gallons_baseline, x.total_population_served, x.days_since
    ), axis=1
)

# %%
district_cumulative_savings_df.sort_values("gallons_saved_per_day", ascending=False)
# Out:
#                                  supplier_name  hydrologic_region  \
# 361                             Vernon City of        South Coast
# 162      Humboldt Bay Municipal Water District        North Coast
# 190                         Livingston City of  San Joaquin River
# 251                            Perris, City of        South Coast
# 54   California Water Service Company Westlake        South Coast
# ..                                         ...                ...
# 173                         Kingsburg, City of        Tulare Lake
# 105                          El Centro City of     Colorado River
# 184                    Lee Lake Water District        South Coast
# 245               Paradise Irrigation District   Sacramento River
# 108                         El Segundo City of        South Coast
#
#      total_gallons_current  total_gallons_baseline  total_population_served  \
# 361         3078373050.180          3337882231.753                      112
# 162           90795000.000           139435000.000                      602
# 190         3428397000.000          4238758000.000                    15052
# 251          789347979.420          1178756964.453                     9000
# 54          2987825574.300          3636640495.868                    19489
# ..                     ...                     ...                      ...
# 173         1631208000.000          1571986000.000                    12338
# 105         4179427000.000          3830804000.000                    46364
# 184         1779007152.737          1597216389.254                    21038
# 245         2073900000.000          1978730000.000                     3000
# 108         3513523194.644          2720507929.610                    16654
#
#      cumulative_pct_change       date  months_since  days_since  \
# 361                 -0.078 2022-12-15            17         548
# 162                 -0.349 2022-12-15            17         548
# 190                 -0.191 2022-12-15            17         548
# 251                 -0.330 2022-12-15            17         548
# 54                  -0.178 2022-12-15            17         548
# ..                     ...        ...           ...         ...
# 173                  0.038 2022-12-15            17         548
# 105                  0.091 2022-12-15            17         548
# 184                  0.114 2022-12-15            17         548
# 245                  0.048 2022-12-15            17         548
# 108                  0.291 2022-12-15            17         548
#
#      gallons_saved_per_month  gallons_saved_per_day
# 361               136296.839               4228.187
# 162                 4752.785                147.440
# 190                 3166.908                 98.243
# 251                 2545.157                 78.956
# 54                  1958.314                 60.751
# ..                       ...                    ...
# 173                 -282.351                 -8.759
# 105                 -442.309                -13.721
# 184                 -508.298                -15.768
# 245                -1866.078                -57.889
# 108                -2801.006                -86.893
#
# [379 rows x 11 columns]

# %%
chart_data = complete_data[complete_data.supplier_name.str.contains("El Segundo")]
name = chart_data.iloc[0]["supplier_name"]

alt.Chart(
    chart_data
).mark_bar().encode(
    x=alt.X('yearmonth(reporting_month):T', axis=alt.Axis(title="Reporting month")),
    y=alt.Y("gallons_pct_change:Q", axis=alt.Axis(format="%", title="Percent change in gallons used")),
    color=alt.condition(
        alt.datum.gallons_pct_change > 0,
        alt.value("#e6ae56"),  # The positive color
        alt.value("#83c6e0")  # The negative color
    ),
    tooltip=["reporting_month","gallons_pct_change"]
).properties(title=f"Monthly water conservation in {name}", width=600)
# Out:
# alt.Chart(...)

# %%
df.iloc[36934]["qualification"]
# Out:
# nan

# %%
df.iloc[18213]['qualification']
# Out:
# nan

# %%
df[
    (df.supplier_name=="Paradise Irrigation District")&
    (df.reporting_month >= "2021-07-15")
]
# Out:
#                       supplier_name public_water_system_id reporting_month  \
# 18387  Paradise Irrigation District              CA0410007      2023-03-15
# 18388  Paradise Irrigation District              CA0410007      2023-02-15
# 18389  Paradise Irrigation District              CA0410007      2023-01-15
# 18390  Paradise Irrigation District              CA0410007      2022-12-15
# 18391  Paradise Irrigation District              CA0410007      2022-11-15
# 18392  Paradise Irrigation District              CA0410007      2022-10-15
# 18393  Paradise Irrigation District              CA0410007      2022-09-15
# 18394  Paradise Irrigation District              CA0410007      2022-08-15
# 18395  Paradise Irrigation District              CA0410007      2022-07-15
# 18396  Paradise Irrigation District              CA0410007      2022-06-15
# 18397  Paradise Irrigation District              CA0410007      2022-05-15
# 18398  Paradise Irrigation District              CA0410007      2022-04-15
# 18399  Paradise Irrigation District              CA0410007      2022-03-15
# 18400  Paradise Irrigation District              CA0410007      2022-02-15
# 18401  Paradise Irrigation District              CA0410007      2022-01-15
# 18402  Paradise Irrigation District              CA0410007      2021-12-15
# 18403  Paradise Irrigation District              CA0410007      2021-11-15
# 18404  Paradise Irrigation District              CA0410007      2021-10-15
# 18405  Paradise Irrigation District              CA0410007      2021-09-15
# 18406  Paradise Irrigation District              CA0410007      2021-08-15
# 18407  Paradise Irrigation District              CA0410007      2021-07-15
#
#       county hydrologic_region  climate_zone  total_population_served  \
# 18387  Butte  Sacramento River            11                     8800
# 18388  Butte  Sacramento River            11                     8800
# 18389  Butte  Sacramento River            11                     8000
# 18390  Butte  Sacramento River            11                     8000
# 18391  Butte  Sacramento River            11                     8000
# 18392  Butte  Sacramento River            11                     8000
# 18393  Butte  Sacramento River            11                     8000
# 18394  Butte  Sacramento River            11                     8000
# 18395  Butte  Sacramento River            11                     8000
# 18396  Butte  Sacramento River            11                     6000
# 18397  Butte  Sacramento River            11                     6000
# 18398  Butte  Sacramento River            11                     6000
# 18399  Butte  Sacramento River            11                     6000
# 18400  Butte  Sacramento River            11                     6000
# 18401  Butte  Sacramento River            11                     6000
# 18402  Butte  Sacramento River            11                     6000
# 18403  Butte  Sacramento River            11                     6000
# 18404  Butte  Sacramento River            11                     6000
# 18405  Butte  Sacramento River            11                     6000
# 18406  Butte  Sacramento River            11                     3000
# 18407  Butte  Sacramento River            11                     3000
#
#        reference_2014_population county_under_drought_declaration  \
# 18387                      26032                              Yes
# 18388                      26032                              Yes
# 18389                      26032                              Yes
# 18390                      26032                              Yes
# 18391                      26032                              Yes
# 18392                      26032                              Yes
# 18393                      26032                              Yes
# 18394                      26032                              Yes
# 18395                      26032                              Yes
# 18396                      26032                              Yes
# 18397                      26032                              Yes
# 18398                      26032                              Yes
# 18399                      26032                              Yes
# 18400                      26032                              Yes
# 18401                      26032                              Yes
# 18402                      26032                              Yes
# 18403                      26032                              Yes
# 18404                      26032                              Yes
# 18405                      26032                              Yes
# 18406                      26032                              Yes
# 18407                      26032                              NaN
#
#       water_shortage_contingency_stage_invoked  ...  \
# 18387                                        1  ...
# 18388                                        1  ...
# 18389                                        0  ...
# 18390                                        1  ...
# 18391                                        1  ...
# 18392                                        1  ...
# 18393                                        1  ...
# 18394                                        1  ...
# 18395                               We haven't  ...
# 18396                               We haven't  ...
# 18397                               We haven't  ...
# 18398                               We haven't  ...
# 18399                               We haven't  ...
# 18400                               We haven't  ...
# 18401                               We haven't  ...
# 18402                               We haven't  ...
# 18403                               We haven't  ...
# 18404                               We haven't  ...
# 18405                               We haven't  ...
# 18406                               We haven't  ...
# 18407                               We haven't  ...
#
#       reported_preliminary_commercial_industrial_and_institutional_water  \
# 18387                                              0.000
# 18388                                              0.000
# 18389                                              0.000
# 18390                                              0.000
# 18391                                              0.000
# 18392                                              0.000
# 18393                                              0.000
# 18394                                              0.000
# 18395                                              0.000
# 18396                                              0.000
# 18397                                              0.000
# 18398                                              0.000
# 18399                                              0.000
# 18400                                              0.000
# 18401                                              0.000
# 18402                                              0.000
# 18403                                              0.000
# 18404                                              0.000
# 18405                                              0.000
# 18406                                              0.000
# 18407                                              0.000
#
#        reported_final_commercial_industrial_and_institutional_water  \
# 18387                                              0.000
# 18388                                              0.000
# 18389                                              0.000
# 18390                                              0.000
# 18391                                              0.000
# 18392                                              0.000
# 18393                                              0.000
# 18394                                              0.000
# 18395                                              0.000
# 18396                                              0.000
# 18397                                              0.000
# 18398                                              0.000
# 18399                                              0.000
# 18400                                              0.000
# 18401                                              0.000
# 18402                                              0.000
# 18403                                              0.000
# 18404                                              0.000
# 18405                                              0.000
# 18406                                              0.000
# 18407                                              0.000
#
#       reported_recycled_water  reported_non_revenue_water  \
# 18387                   0.000                       0.000
# 18388                   0.000                       0.000
# 18389                   0.000                       0.000
# 18390                   0.000                       0.000
# 18391                   0.000                       0.000
# 18392                   0.000                       0.000
# 18393                   0.000                       0.000
# 18394                   0.000                       0.000
# 18395                   0.000                       0.000
# 18396                   0.000                       0.000
# 18397                   0.000                       0.000
# 18398                   0.000                       0.000
# 18399                   0.000                       0.000
# 18400                   0.000                       0.000
# 18401                   0.000                       0.000
# 18402                   0.000                       0.000
# 18403                   0.000                       0.000
# 18404                   0.000                       0.000
# 18405                   0.000                       0.000
# 18406                   0.000                       0.000
# 18407                   0.000                       0.000
#
#        calculated_total_potable_water_production_gallons_ag_excluded  \
# 18387                                       72600000.000
# 18388                                       69300000.000
# 18389                                       74900000.000
# 18390                                       78100000.000
# 18391                                       82800000.000
# 18392                                      131600000.000
# 18393                                      144400000.000
# 18394                                      174200000.000
# 18395                                      162400000.000
# 18396                                      122600000.000
# 18397                                      105300000.000
# 18398                                       75200000.000
# 18399                                       81000000.000
# 18400                                       78000000.000
# 18401                                       82600000.000
# 18402                                       72800000.000
# 18403                                       57700000.000
# 18404                                      105900000.000
# 18405                                      150600000.000
# 18406                                      174700000.000
# 18407                                      194000000.000
#
#        calculated_total_potable_water_production_gallons_2013_ag_excluded  \
# 18387                                      101600000.000
# 18388                                       76100000.000
# 18389                                       82500000.000
# 18390                                      102300000.000
# 18391                                      117400000.000
# 18392                                      170700000.000
# 18393                                      230100000.000
# 18394                                      309900000.000
# 18395                                      327500000.000
# 18396                                      276200000.000
# 18397                                      241600000.000
# 18398                                      145100000.000
# 18399                                      101600000.000
# 18400                                       76100000.000
# 18401                                       82500000.000
# 18402                                      102300000.000
# 18403                                      117400000.000
# 18404                                      170700000.000
# 18405                                      230100000.000
# 18406                                      309900000.000
# 18407                                      327500000.000
#
#        calculated_commercial_agricultural_water_gallons  \
# 18387                                             0.000
# 18388                                             0.000
# 18389                                             0.000
# 18390                                             0.000
# 18391                                             0.000
# 18392                                             0.000
# 18393                                             0.000
# 18394                                             0.000
# 18395                                             0.000
# 18396                                             0.000
# 18397                                             0.000
# 18398                                             0.000
# 18399                                             0.000
# 18400                                             0.000
# 18401                                             0.000
# 18402                                             0.000
# 18403                                             0.000
# 18404                                             0.000
# 18405                                             0.000
# 18406                                             0.000
# 18407                                             0.000
#
#        calculated_commercial_agricultural_water_gallons_2013  \
# 18387                                              0.000
# 18388                                              0.000
# 18389                                              0.000
# 18390                                              0.000
# 18391                                              0.000
# 18392                                              0.000
# 18393                                              0.000
# 18394                                              0.000
# 18395                                              0.000
# 18396                                              0.000
# 18397                                              0.000
# 18398                                              0.000
# 18399                                              0.000
# 18400                                              0.000
# 18401                                              0.000
# 18402                                              0.000
# 18403                                              0.000
# 18404                                              0.000
# 18405                                              0.000
# 18406                                              0.000
# 18407                                              0.000
#
#        calculated_r_gpcd                                      qualification
# 18387             25.689          still working on meters to all customers.
# 18388             26.883                     Still working on meter system.
# 18389             29.032                           Still working on meters.
# 18390             30.194                                                NaN
# 18391             33.200  Meter project still underway. Majority should ...
# 18392             51.097  Meter project still underway. Majority should ...
# 18393             57.600                  Still in recovery mode from fire.
# 18394             67.355                                                NaN
# 18395             62.710              Still working on the metering system.
# 18396             65.600                  Still working on meters to homes.
# 18397             54.194   We are still working on our metering system d...
# 18398             40.000  We continue to work on our metering system. Th...
# 18399             41.806  Continue working on meter installation. Projec...
# 18400             44.571  The District continues to work on its metering...
# 18401             42.839  We are still working on installing meters on o...
# 18402             37.677  We still are working on our metering system af...
# 18403             30.933  We are still working on our metering system. E...
# 18404             54.710  We are still working on our meter system. The ...
# 18405             80.533  We are still working on our water meter system...
# 18406            180.645  Due to the 2018 Camp Fire we are still without...
# 18407            200.258  We are still without a meter system.  Hope to ...
#
# [21 rows x 29 columns]

# %%
complete_data[
    (complete_data.supplier_name=="El Segundo City of")&
    (complete_data.reporting_month >= "2021-07-15") &
    (complete_data.reporting_month != "2021-08-15")
].groupby("supplier_name")[["total_gallons_current","total_gallons_baseline"]].sum().reset_index()
# Out:
#         supplier_name  total_gallons_current  total_gallons_baseline
# 0  El Segundo City of         3187329135.628          2530903424.018

# %%
chart_data = complete_data[complete_data.supplier_name == "Los Angeles Department of Water and Power"]
name = chart_data.iloc[0]["supplier_name"]

alt.Chart(
    chart_data
).mark_bar().encode(
    x=alt.X('yearmonth(reporting_month):T', axis=alt.Axis(title="Reporting month")),
    y=alt.Y("gallons_pct_change:Q", axis=alt.Axis(format="%", title="Percent change in gallons used")),
    color=alt.condition(
        alt.datum.gallons_pct_change > 0,
        alt.value("#e6ae56"),  # The positive color
        alt.value("#83c6e0")  # The negative color
    ),
    tooltip=["reporting_month","gallons_pct_change"]
).properties(title=f"Monthly water conservation in {name}", width=600)
# Out:
# alt.Chart(...)

# %%
alt.Chart(
    complete_data[complete_data.supplier_name.str.contains("El Segundo")]
).mark_bar().encode(
    x=alt.X('yearmonth(reporting_month):T'),
    y="total_gallons_current",
    tooltip=["reporting_month"]
).properties(width=600)
# Out:
# alt.Chart(...)

# %% [markdown]
# Drop districts for which we can't calculate a percentage change

# %%
drop_na_districts = district_cumulative_savings_df.dropna(subset="cumulative_pct_change")

# %% [markdown]
# By region

# %%
regions_cumulative_savings_df = district_cumulative_savings_df.groupby(
    ["hydrologic_region"]
)[
    ["total_gallons_current","total_gallons_baseline","supplier_name"]
].agg(
    {"total_gallons_current":"sum","total_gallons_baseline":"sum","supplier_name":"size"}
).reset_index().rename(
    columns={"supplier_name": "total_reports"}
)

# %%
regions_cumulative_savings_df = pd.merge(
    regions_cumulative_savings_df,
    pops_by_region[["hydrologic_region","total_population_served"]],
    how="left",
    on="hydrologic_region"
)

# %%
regions_cumulative_savings_df["cumulative_pct_change"] = regions_cumulative_savings_df.apply(lambda x: pct_change(x.total_gallons_current, x.total_gallons_baseline), axis=1)

# %%
regions_cumulative_savings_df['date'] = date

# %%
regions_cumulative_savings_df['months_since'] = months_since_reductions_begin
regions_cumulative_savings_df['days_since'] = days_since_reductions

# %%
regions_cumulative_savings_df['gallons_saved_per_month'] = regions_cumulative_savings_df.apply(
    lambda x: gallons_per_unit(
        x.total_gallons_current, x.total_gallons_baseline, x.total_population_served, x.months_since
    ), axis=1
)

# %%
regions_cumulative_savings_df['gallons_saved_per_day'] = regions_cumulative_savings_df.apply(
    lambda x: gallons_per_unit(
        x.total_gallons_current, x.total_gallons_baseline, x.total_population_served, x.days_since
    ), axis=1
)

# %%
regions_cumulative_savings_df
# Out:
#    hydrologic_region  total_gallons_current  total_gallons_baseline  \
# 0      Central Coast        68867849211.629         72263664590.905
# 1     Colorado River       101551584092.535        103768495116.159
# 2        North Coast        21594248693.920         25401832502.965
# 3     North Lahontan         7166845519.000          7900971365.000
# 4   Sacramento River       282181222898.392        306040235246.434
# 5  San Francisco Bay       357990226031.495        403652152366.566
# 6  San Joaquin River       147394515783.934        154516401013.528
# 7        South Coast      1378044056828.539       1448241947289.353
# 8     South Lahontan        69678858952.980         74427286370.858
# 9        Tulare Lake       216447171526.326        223611282792.950
#
#    total_reports  total_population_served  cumulative_pct_change       date  \
# 0             27                  1293270                 -0.047 2022-12-15
# 1             12                   780308                 -0.021 2022-12-15
# 2             16                   414740                 -0.150 2022-12-15
# 3              5                   103768                 -0.093 2022-12-15
# 4             43                  2843842                 -0.078 2022-12-15
# 5             45                  6671142                 -0.113 2022-12-15
# 6             25                  1706054                 -0.046 2022-12-15
# 7            161                 20450766                 -0.048 2022-12-15
# 8             16                   863361                 -0.064 2022-12-15
# 9             29                  1982976                 -0.032 2022-12-15
#
#    months_since  days_since  gallons_saved_per_month  gallons_saved_per_day
# 0            17         548                  154.456                  4.792
# 1            17         548                  167.122                  5.184
# 2            17         548                  540.038                 16.753
# 3            17         548                  416.158                 12.910
# 4            17         548                  493.512                 15.310
# 5            17         548                  402.629                 12.490
# 6            17         548                  245.558                  7.618
# 7            17         548                  201.914                  6.264
# 8            17         548                  323.525                 10.036
# 9            17         548                  212.518                  6.593

# %%
chart_data = regions_df[regions_df.hydrologic_region=="South Coast"]
name = chart_data.iloc[0]["hydrologic_region"]

alt.Chart(
    chart_data
).mark_bar().encode(
    x=alt.X('yearmonth(reporting_month):T'),
    y="gallons_pct_change:Q",
    color=alt.condition(
        alt.datum.gallons_pct_change > 0,
        alt.value("#e6ae56"),  # The positive color
        alt.value("#83c6e0")  # The negative color
    ),
    tooltip=["reporting_month","gallons_pct_change"]
).properties(title=f"Monthly water conservation in {name}", width=600)
# Out:
# alt.Chart(...)

# %% [markdown]
# Statewide

# %%
district_cumulative_savings_df["state"] = "California"

# %%
statewide_cumulative_savings_df = district_cumulative_savings_df.groupby(
    ["state"]
)[
    ["total_gallons_current","total_gallons_baseline", "supplier_name"]
].agg({
    "total_gallons_current": "sum",
    "total_gallons_baseline": "sum",
    "supplier_name": "size"
}).reset_index().rename(
    columns={"supplier_name": "total_reports"}
)

# %%
#statewide_cumulative_savings_df["total_reports"] = statewide_cumulative_savings_df["total_reports"]

# %%
statewide_cumulative_savings_df["total_population_served"] = pop_state

# %%
statewide_cumulative_savings_df["cumulative_pct_change"] = statewide_cumulative_savings_df.apply(lambda x: pct_change(x.total_gallons_current, x.total_gallons_baseline), axis=1)

# %%
statewide_cumulative_savings_df['date'] = date

# %%
statewide_cumulative_savings_df['months_since'] = months_since_reductions_begin
statewide_cumulative_savings_df['days_since'] = days_since_reductions

# %%
statewide_cumulative_savings_df['gallons_saved_per_month'] = regions_cumulative_savings_df.apply(
    lambda x: gallons_per_unit(
        x.total_gallons_current, x.total_gallons_baseline, x.total_population_served, x.months_since
    ), axis=1
)

# %%
statewide_cumulative_savings_df['gallons_saved_per_day'] = statewide_cumulative_savings_df.apply(
    lambda x: gallons_per_unit(
        x.total_gallons_current, x.total_gallons_baseline, x.total_population_served, x.days_since
    ), axis=1
)

# %%
statewide_cumulative_savings_df
# Out:
#         state  total_gallons_current  total_gallons_baseline  total_reports  \
# 0  California      2650916579538.750       2819824268654.718            379
#
#    total_population_served  cumulative_pct_change       date  months_since  \
# 0                 37110227                 -0.060 2022-12-15            17
#
#    days_since  gallons_saved_per_month  gallons_saved_per_day
# 0         548                  154.456                  8.306

# %%
alt.Chart(
    statewide_df
).mark_bar().encode(
    x=alt.X('yearmonth(reporting_month):T', axis=alt.Axis(title="Reporting month")),
    y=alt.Y("gallons_pct_change:Q", axis=alt.Axis(format="%", title="Percent change in gallons used")),
    color=alt.condition(
        alt.datum.gallons_pct_change > 0,
        alt.value("#e6ae56"),  # The positive color
        alt.value("#83c6e0")  # The negative color
    ),
    tooltip=["reporting_month","gallons_pct_change"]
).properties(title=f"Monthly water conservation in California", width=600)
# Out:
# alt.Chart(...)

# %% [markdown]
# ### Export

# %%
statewide_cumulative_savings_df.to_csv(
    "../data/processed/cumulative-conservation/cumulative-savings/statewide-cumulative-savings.csv",
    index=False
)

# %%
regions_cumulative_savings_df.to_csv(
    "../data/processed/cumulative-conservation/cumulative-savings/regional-cumulative-savings.csv",
    index=False
)

# %%
district_cumulative_savings_df.to_csv(
    "../data/processed/cumulative-conservation/cumulative-savings/district-cumulative-savings.csv",
    index=False
)
