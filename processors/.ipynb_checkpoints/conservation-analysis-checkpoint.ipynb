# %%
import pandas as pd
import altair as alt
import altair_latimes as lat
from pandas.tseries.offsets import MonthEnd

# %%
alt.themes.register('latimes', lat.theme)
alt.themes.enable('latimes')
# Out:
# ThemeRegistry.enable('latimes')

# %%
pd.set_option('display.float_format', lambda x: '%.3f' % x)

# %% [markdown]
# ### Import

# %%
df = pd.read_csv("../data/raw/uw-usage.csv", parse_dates=["Reporting Month"])

# %%
baselines_df = pd.read_csv("../data/raw/uw-2020-baseline-values.csv")

# %% [markdown]
# ### Clean

# %% [markdown]
# Remove junk from column names

# %%
df.columns = df.columns.str.replace(" ","_").str.replace("-","_").str.replace(r'[#,@,&,(,)]', '', regex=True).str.lower()

# %% [markdown]
# Eliminate double spaces in supplier names

# %%
df.supplier_name = df.supplier_name.str.replace("  ", " ")

# %% [markdown]
# Clean up baselines column names as we did in the previous notebook

# %%
baselines_df.columns = baselines_df.columns.str.replace(" ","_").str.replace("-","_").str.replace(r'[#,@,&,(,)]', '', regex=True).str.lower()

# %%
baselines_df.supplier_name = baselines_df.supplier_name.str.replace("  ", " ")

# %%
baselines_trimmed_df = baselines_df[[
    'supplier_name', 
    'public_water_system_id', 
    'month', 
    #'original_units',
    # 'total_potable_production_original_units',
    # 'potable_commercial_agriculture_original_units',
    'total_potable_production_minus_ag_gallons', 
    # 'staff_notes'
]].copy()

# %% [markdown]
# Get rid of some unnecessary columns

# %%
trim_df = df[[
    'supplier_name', 
    'public_water_system_id', 
    'reporting_month', 
    'county',
    'hydrologic_region', 
    'climate_zone', 
    'total_population_served',
    'calculated_total_potable_water_production_gallons_ag_excluded',
    'calculated_r_gpcd', 
    # 'month'
]].copy()

# %% [markdown]
# ### Get populations by supplier, hydrologic region and state total

# %% [markdown]
# Using populations from the beginning of the drought emergency

# %%
pops_by_supplier = df[
    df.reporting_month == "2021-07-15"
][["supplier_name","hydrologic_region","total_population_served"]]

# %%
pops_by_region = pops_by_supplier.groupby(
    ["hydrologic_region"]
)["total_population_served"].sum().reset_index()

# %%
pop_state = pops_by_region.total_population_served.sum()
pop_state
# Out:
# 37110170

# %% [markdown]
# ### Merge

# %% [markdown]
# Filter df to July 2021 and later

# %%
filter_df = trim_df[trim_df.reporting_month >= "2021-07-15"].copy()

# %% [markdown]
# Remove -999999999

# %%
filter_df = filter_df[filter_df.calculated_total_potable_water_production_gallons_ag_excluded != -999999999]

# %% [markdown]
# Make a month column to merge with baselines

# %%
filter_df["month"] = filter_df["reporting_month"].dt.month

# %%
merge_df = pd.merge(
    filter_df, 
    baselines_trimmed_df, 
    how="left", 
    on=["supplier_name", "public_water_system_id", "month"]
).rename(
    columns={
        "calculated_total_potable_water_production_gallons_ag_excluded": "total_gallons_current",
        "total_potable_production_minus_ag_gallons": "total_gallons_baseline"
    }
).drop("month", axis=1)

# %% [markdown]
# ### Remove duplicates

# %%
tmp = merge_df.set_index(['supplier_name', 'reporting_month'])

# %%
merge_df = tmp[~tmp.index.duplicated()].reset_index()

# %% [markdown]
# ### Calculate percent changes by month

# %%
def pct_change(new, old):
    return (new - old) / old

# %% [markdown]
# By supplier

# %%
merge_df["gallons_pct_change"] = merge_df.apply(lambda x: pct_change(x.total_gallons_current, x.total_gallons_baseline), axis=1)

# %% [markdown]
# Filter out outliers

# %%
# lower_thresh=-0.5
# upper_thresh=1.3

# %%
# districts_filtered = merge_df[
#     (merge_df['gallons_pct_change']<upper_thresh)&(merge_df['gallons_pct_change']>lower_thresh)
# ]

# %% [markdown]
# By region

# %%
regions_df = merge_df.groupby(
    ["hydrologic_region", "reporting_month"]
)[["total_gallons_current","total_gallons_baseline", "supplier_name"]].agg({
    "total_gallons_current":"sum",
    "total_gallons_baseline":"sum",
    "supplier_name":"size"
}).reset_index()

# %%
regions_df["gallons_pct_change"] = regions_df.apply(lambda x: pct_change(x.total_gallons_current, x.total_gallons_baseline), axis=1)

# %% [markdown]
# Statewide

# %%
merge_df["state"] = "Statewide"

# %%
statewide_df = merge_df.groupby(["state", "reporting_month"])[["total_gallons_current","total_gallons_baseline"]].sum().reset_index()

# %%
statewide_df["gallons_pct_change"] = statewide_df.apply(lambda x: pct_change(x.total_gallons_current, x.total_gallons_baseline), axis=1)

# %% [markdown]
# ### Calculate cumulative savings since July 2021

# %% [markdown]
# Set up some vars and function

# %%
def month_diff(a, b):
    return 12 * (a.year - b.year) + (a.month - b.month)

# %%
def gallons_per_unit(gallons, baseline, population, time):
    return ((baseline - gallons) / population) / time

# %%
# voluntary_reductions_begin = pd.to_datetime('2021-07-08')
voluntary_reductions_begin = pd.to_datetime('2021-07-01')
voluntary_reductions_begin
# Out:
# Timestamp('2021-07-01 00:00:00')

# %%
latest_month = statewide_df[
    statewide_df.reporting_month == statewide_df.reporting_month.max()
].iloc[0]['reporting_month']

latest_month = pd.to_datetime(latest_month, format="%Y%m") + MonthEnd(0)

latest_month
# Out:
# Timestamp('2023-02-28 00:00:00')

# %%
months_since_reductions_begin = month_diff(latest_month, voluntary_reductions_begin)
months_since_reductions_begin
# Out:
# 19

# %%
days_since_reductions = (latest_month - voluntary_reductions_begin).days
days_since_reductions
# Out:
# 607

# %% [markdown]
# Get date of this monthly report

# %%
date = statewide_df[
    (statewide_df.reporting_month==statewide_df.reporting_month.max())
].iloc[0]["reporting_month"]

# %% [markdown]
# Drop suppliers with missing data

# %%
counts = merge_df.groupby("supplier_name")["reporting_month"].count().reset_index()

# %%
max_count = max(counts.reporting_month)
max_count
# Out:
# 20

# %%
suppliers_with_complete_data = list(counts[counts.reporting_month == max_count].supplier_name)

# %%
complete_data = merge_df[merge_df.supplier_name.isin(suppliers_with_complete_data)].copy()

# %%
complete_data[complete_data.reporting_month == "2022-02-15"]
# Out:
#                               supplier_name reporting_month  \
# 12    East Bay Municipal Utilities District      2022-02-15
# 49               Yorba Linda Water District      2022-02-15
# 69                       Long Beach City of      2022-02-15
# 89                       Los Banos, City of      2022-02-15
# 109                         Turlock City of      2022-02-15
# ...                                     ...             ...
# 7890                      Corcoran, City of      2022-02-15
# 7910        City of Newman Water Department      2022-02-15
# 8004       Greenfield County Water District      2022-02-15
# 8043    Thermalito Water and Sewer District      2022-02-15
# 8063      Santa Clarita Valley Water Agency      2022-02-15
#
#                                  public_water_system_id                county  \
# 12                                            CA0110005  Alameda,Contra Costa
# 49                                            CA3010037                Orange
# 69                                            CA1910065           Los Angeles
# 89                                            CA2410005                Merced
# 109                                           CA5010019            Stanislaus
# ...                                                 ...                   ...
# 7890                                          CA1610004                 Kings
# 7910                                          CA5010013            Stanislaus
# 8004                                          CA1510024                  Kern
# 8043                                          CA0410008                 Butte
# 8063  CA1910255,CA1910247,CA1910096,CA1910250,CA1910...           Los Angeles
#
#       hydrologic_region  climate_zone  total_population_served  \
# 12    San Francisco Bay             3                  1430000
# 49          South Coast             8                    80540
# 69          South Coast             6                   467730
# 89    San Joaquin River            12                    44391
# 109   San Joaquin River            12                    74297
# ...                 ...           ...                      ...
# 7890        Tulare Lake            13                    13593
# 7910  San Joaquin River            12                    11801
# 8004        Tulare Lake             4                    11428
# 8043   Sacramento River            11                    10339
# 8063        South Coast             9                   295639
#
#       total_gallons_current  calculated_r_gpcd  total_gallons_baseline  \
# 12           3898000000.000             55.491          4084900000.000
# 49            430256918.910            157.926           518275791.030
# 69           1158726156.000             56.625          1252247033.961
# 89            150586000.000             77.537           144716000.000
# 109           364551000.000             88.183           382770000.000
# ...                     ...                ...                     ...
# 7890          103533000.000             45.359           100475000.000
# 7910           38631264.000             75.760            39505000.000
# 8004           46588339.000            119.534            43408000.000
# 8043           34724573.840             99.319            33420581.964
# 8063         1361669417.310            119.049          1263156539.737
#
#       gallons_pct_change      state
# 12                -0.046  Statewide
# 49                -0.170  Statewide
# 69                -0.075  Statewide
# 89                 0.041  Statewide
# 109               -0.048  Statewide
# ...                  ...        ...
# 7890               0.030  Statewide
# 7910              -0.022  Statewide
# 8004               0.073  Statewide
# 8043               0.039  Statewide
# 8063               0.078  Statewide
#
# [332 rows x 12 columns]

# %% [markdown]
# By district

# %%
district_cumulative_savings_df = complete_data.groupby(
    ["supplier_name","hydrologic_region"]
)[["total_gallons_current","total_gallons_baseline"]].sum().reset_index()

# %%
district_cumulative_savings_df = pd.merge(
    district_cumulative_savings_df,
    pops_by_supplier[["supplier_name","hydrologic_region","total_population_served"]],
    how="left",
    on=["supplier_name","hydrologic_region"]
)

# %%
district_cumulative_savings_df["cumulative_pct_change"] = district_cumulative_savings_df.apply(lambda x: pct_change(x.total_gallons_current, x.total_gallons_baseline), axis=1)

# %%
district_cumulative_savings_df['date'] = date

# %%
district_cumulative_savings_df['months_since'] = months_since_reductions_begin
district_cumulative_savings_df['days_since'] = days_since_reductions

# %%
district_cumulative_savings_df['gallons_saved_per_month'] = district_cumulative_savings_df.apply(
    lambda x: gallons_per_unit(
        x.total_gallons_current, x.total_gallons_baseline, x.total_population_served, x.months_since
    ), axis=1
)

# %%
district_cumulative_savings_df['gallons_saved_per_day'] = district_cumulative_savings_df.apply(
    lambda x: gallons_per_unit(
        x.total_gallons_current, x.total_gallons_baseline, x.total_population_served, x.days_since
    ), axis=1
)

# %%
district_cumulative_savings_df.sort_values("gallons_saved_per_day", ascending=False)
# Out:
#                                  supplier_name  hydrologic_region  \
# 315                             Vernon City of        South Coast
# 171                         Livingston City of  San Joaquin River
# 52   California Water Service Company Westlake        South Coast
# 313    Ventura County Waterworks District No 1        South Coast
# 142                         Healdsburg City of        North Coast
# ..                                         ...                ...
# 156                         Kingsburg, City of        Tulare Lake
# 206               Oildale Mutual Water Company        Tulare Lake
# 97                           El Centro City of     Colorado River
# 217               Paradise Irrigation District   Sacramento River
# 100                         El Segundo City of        South Coast
#
#      total_gallons_current  total_gallons_baseline  total_population_served  \
# 315         3346040095.620          3701434192.453                      112
# 171         3682207000.000          4623882000.000                    15052
# 52          3148600457.700          3915712467.357                    19489
# 313         3581167660.200          4775584874.894                    36284
# 142          699538372.000          1078507656.000                    11800
# ..                     ...                     ...                      ...
# 156         1716940000.000          1670046000.000                    12338
# 206         4939852282.350          4790309243.184                    34133
# 97          4470845000.000          4116148000.000                    46364
# 217         2218100000.000          2084610000.000                     3000
# 100         3802735058.884          3006804269.876                    16654
#
#      cumulative_pct_change       date  months_since  days_since  \
# 315                 -0.096 2023-02-15            19         607
# 171                 -0.204 2023-02-15            19         607
# 52                  -0.196 2023-02-15            19         607
# 313                 -0.250 2023-02-15            19         607
# 142                 -0.351 2023-02-15            19         607
# ..                     ...        ...           ...         ...
# 156                  0.028 2023-02-15            19         607
# 206                  0.031 2023-02-15            19         607
# 97                   0.086 2023-02-15            19         607
# 217                  0.064 2023-02-15            19         607
# 100                  0.265 2023-02-15            19         607
#
#      gallons_saved_per_month  gallons_saved_per_day       state
# 315               167008.504               5227.614  California
# 171                 3292.708                103.067  California
# 52                  2071.646                 64.846  California
# 313                 1732.556                 54.232  California
# 142                 1690.318                 52.909  California
# ..                       ...                    ...         ...
# 156                 -200.041                 -6.262  California
# 206                 -230.589                 -7.218  California
# 97                  -402.646                -12.603  California
# 217                -2341.930                -73.306  California
# 100                -2515.377                -78.735  California
#
# [332 rows x 12 columns]

# %%
chart_data = complete_data[complete_data.supplier_name.str.contains("El Segundo")]
name = chart_data.iloc[0]["supplier_name"]

alt.Chart(
    chart_data
).mark_bar().encode(
    x=alt.X('yearmonth(reporting_month):T', axis=alt.Axis(title="Reporting month")),
    y=alt.Y("gallons_pct_change:Q", axis=alt.Axis(format="%", title="Percent change in gallons used")),
    color=alt.condition(
        alt.datum.gallons_pct_change > 0,
        alt.value("#e6ae56"),  # The positive color
        alt.value("#83c6e0")  # The negative color
    ),
    tooltip=["reporting_month","gallons_pct_change"]
).properties(title=f"Monthly water conservation in {name}", width=600)
# Out:
# alt.Chart(...)

# %%
df.iloc[36934]["qualification"]
# Out:
# 'The Hyperion Treatment Plant that is normally the source of the high volumes of recycled water reported from the City had issues causing our potable water customer West Basin to pull large volumes of potable water from our water system. The results will show in the higher than average potable production number on this report that is also present in the Commercial potable number. As well as the lower than average recycled water number.'

# %%
df.iloc[18213]['qualification']
# Out:
# 'Meter project still underway. Majority should be online by end of first quarter 2023'

# %%
df[
    (df.supplier_name=="Paradise Irrigation District")&
    (df.reporting_month >= "2021-07-15")
]
# Out:
#                       supplier_name public_water_system_id reporting_month  \
# 18210  Paradise Irrigation District              CA0410007      2023-02-15
# 18211  Paradise Irrigation District              CA0410007      2023-01-15
# 18212  Paradise Irrigation District              CA0410007      2022-12-15
# 18213  Paradise Irrigation District              CA0410007      2022-11-15
# 18214  Paradise Irrigation District              CA0410007      2022-10-15
# 18215  Paradise Irrigation District              CA0410007      2022-09-15
# 18216  Paradise Irrigation District              CA0410007      2022-08-15
# 18217  Paradise Irrigation District              CA0410007      2022-07-15
# 18218  Paradise Irrigation District              CA0410007      2022-06-15
# 18219  Paradise Irrigation District              CA0410007      2022-05-15
# 18220  Paradise Irrigation District              CA0410007      2022-04-15
# 18221  Paradise Irrigation District              CA0410007      2022-03-15
# 18222  Paradise Irrigation District              CA0410007      2022-02-15
# 18223  Paradise Irrigation District              CA0410007      2022-01-15
# 18224  Paradise Irrigation District              CA0410007      2021-12-15
# 18225  Paradise Irrigation District              CA0410007      2021-11-15
# 18226  Paradise Irrigation District              CA0410007      2021-10-15
# 18227  Paradise Irrigation District              CA0410007      2021-09-15
# 18228  Paradise Irrigation District              CA0410007      2021-08-15
# 18229  Paradise Irrigation District              CA0410007      2021-07-15
#
#       county hydrologic_region  climate_zone  total_population_served  \
# 18210  Butte  Sacramento River            11                     8800
# 18211  Butte  Sacramento River            11                     8000
# 18212  Butte  Sacramento River            11                     8000
# 18213  Butte  Sacramento River            11                     8000
# 18214  Butte  Sacramento River            11                     8000
# 18215  Butte  Sacramento River            11                     8000
# 18216  Butte  Sacramento River            11                     8000
# 18217  Butte  Sacramento River            11                     8000
# 18218  Butte  Sacramento River            11                     6000
# 18219  Butte  Sacramento River            11                     6000
# 18220  Butte  Sacramento River            11                     6000
# 18221  Butte  Sacramento River            11                     6000
# 18222  Butte  Sacramento River            11                     6000
# 18223  Butte  Sacramento River            11                     6000
# 18224  Butte  Sacramento River            11                     6000
# 18225  Butte  Sacramento River            11                     6000
# 18226  Butte  Sacramento River            11                     6000
# 18227  Butte  Sacramento River            11                     6000
# 18228  Butte  Sacramento River            11                     3000
# 18229  Butte  Sacramento River            11                     3000
#
#        reference_2014_population county_under_drought_declaration  \
# 18210                      26032                              Yes
# 18211                      26032                              Yes
# 18212                      26032                              Yes
# 18213                      26032                              Yes
# 18214                      26032                              Yes
# 18215                      26032                              Yes
# 18216                      26032                              Yes
# 18217                      26032                              Yes
# 18218                      26032                              Yes
# 18219                      26032                              Yes
# 18220                      26032                              Yes
# 18221                      26032                              Yes
# 18222                      26032                              Yes
# 18223                      26032                              Yes
# 18224                      26032                              Yes
# 18225                      26032                              Yes
# 18226                      26032                              Yes
# 18227                      26032                              Yes
# 18228                      26032                              Yes
# 18229                      26032                              NaN
#
#       water_shortage_contingency_stage_invoked  ...  \
# 18210                                        1  ...
# 18211                                        0  ...
# 18212                                        1  ...
# 18213                                        1  ...
# 18214                                        1  ...
# 18215                                        1  ...
# 18216                                        1  ...
# 18217                               We haven't  ...
# 18218                               We haven't  ...
# 18219                               We haven't  ...
# 18220                               We haven't  ...
# 18221                               We haven't  ...
# 18222                               We haven't  ...
# 18223                               We haven't  ...
# 18224                               We haven't  ...
# 18225                               We haven't  ...
# 18226                               We haven't  ...
# 18227                               We haven't  ...
# 18228                               We haven't  ...
# 18229                               We haven't  ...
#
#       reported_preliminary_commercial_industrial_and_institutional_water  \
# 18210                                              0.000
# 18211                                              0.000
# 18212                                              0.000
# 18213                                              0.000
# 18214                                              0.000
# 18215                                              0.000
# 18216                                              0.000
# 18217                                              0.000
# 18218                                              0.000
# 18219                                              0.000
# 18220                                              0.000
# 18221                                              0.000
# 18222                                              0.000
# 18223                                              0.000
# 18224                                              0.000
# 18225                                              0.000
# 18226                                              0.000
# 18227                                              0.000
# 18228                                              0.000
# 18229                                              0.000
#
#        reported_final_commercial_industrial_and_institutional_water  \
# 18210                                              0.000
# 18211                                              0.000
# 18212                                              0.000
# 18213                                              0.000
# 18214                                              0.000
# 18215                                              0.000
# 18216                                              0.000
# 18217                                              0.000
# 18218                                              0.000
# 18219                                              0.000
# 18220                                              0.000
# 18221                                              0.000
# 18222                                              0.000
# 18223                                              0.000
# 18224                                              0.000
# 18225                                              0.000
# 18226                                              0.000
# 18227                                              0.000
# 18228                                              0.000
# 18229                                              0.000
#
#       reported_recycled_water  reported_non_revenue_water  \
# 18210                   0.000                       0.000
# 18211                   0.000                       0.000
# 18212                   0.000                       0.000
# 18213                   0.000                       0.000
# 18214                   0.000                       0.000
# 18215                   0.000                       0.000
# 18216                   0.000                       0.000
# 18217                   0.000                       0.000
# 18218                   0.000                       0.000
# 18219                   0.000                       0.000
# 18220                   0.000                       0.000
# 18221                   0.000                       0.000
# 18222                   0.000                       0.000
# 18223                   0.000                       0.000
# 18224                   0.000                       0.000
# 18225                   0.000                       0.000
# 18226                   0.000                       0.000
# 18227                   0.000                       0.000
# 18228                   0.000                       0.000
# 18229                   0.000                       0.000
#
#        calculated_total_potable_water_production_gallons_ag_excluded  \
# 18210                                       69300000.000
# 18211                                       74900000.000
# 18212                                       78100000.000
# 18213                                       82800000.000
# 18214                                      131600000.000
# 18215                                      144400000.000
# 18216                                      174200000.000
# 18217                                      162400000.000
# 18218                                      122600000.000
# 18219                                      105300000.000
# 18220                                       75200000.000
# 18221                                       81000000.000
# 18222                                       78000000.000
# 18223                                       82600000.000
# 18224                                       72800000.000
# 18225                                       57700000.000
# 18226                                      105900000.000
# 18227                                      150600000.000
# 18228                                      174700000.000
# 18229                                      194000000.000
#
#        calculated_total_potable_water_production_gallons_2013_ag_excluded  \
# 18210                                       76100000.000
# 18211                                       82500000.000
# 18212                                      102300000.000
# 18213                                      117400000.000
# 18214                                      170700000.000
# 18215                                      230100000.000
# 18216                                      309900000.000
# 18217                                      327500000.000
# 18218                                      276200000.000
# 18219                                      241600000.000
# 18220                                      145100000.000
# 18221                                      101600000.000
# 18222                                       76100000.000
# 18223                                       82500000.000
# 18224                                      102300000.000
# 18225                                      117400000.000
# 18226                                      170700000.000
# 18227                                      230100000.000
# 18228                                      309900000.000
# 18229                                      327500000.000
#
#        calculated_commercial_agricultural_water_gallons  \
# 18210                                             0.000
# 18211                                             0.000
# 18212                                             0.000
# 18213                                             0.000
# 18214                                             0.000
# 18215                                             0.000
# 18216                                             0.000
# 18217                                             0.000
# 18218                                             0.000
# 18219                                             0.000
# 18220                                             0.000
# 18221                                             0.000
# 18222                                             0.000
# 18223                                             0.000
# 18224                                             0.000
# 18225                                             0.000
# 18226                                             0.000
# 18227                                             0.000
# 18228                                             0.000
# 18229                                             0.000
#
#        calculated_commercial_agricultural_water_gallons_2013  \
# 18210                                              0.000
# 18211                                              0.000
# 18212                                              0.000
# 18213                                              0.000
# 18214                                              0.000
# 18215                                              0.000
# 18216                                              0.000
# 18217                                              0.000
# 18218                                              0.000
# 18219                                              0.000
# 18220                                              0.000
# 18221                                              0.000
# 18222                                              0.000
# 18223                                              0.000
# 18224                                              0.000
# 18225                                              0.000
# 18226                                              0.000
# 18227                                              0.000
# 18228                                              0.000
# 18229                                              0.000
#
#        calculated_r_gpcd                                      qualification
# 18210             26.883                     Still working on meter system.
# 18211             29.032                           Still working on meters.
# 18212             30.194                                                NaN
# 18213             33.200  Meter project still underway. Majority should ...
# 18214             51.097  Meter project still underway. Majority should ...
# 18215             57.600                  Still in recovery mode from fire.
# 18216             67.355                                                NaN
# 18217             62.710              Still working on the metering system.
# 18218             65.600                  Still working on meters to homes.
# 18219             54.194   We are still working on our metering system d...
# 18220             40.000  We continue to work on our metering system. Th...
# 18221             41.806  Continue working on meter installation. Projec...
# 18222             44.571  The District continues to work on its metering...
# 18223             42.839  We are still working on installing meters on o...
# 18224             37.677  We still are working on our metering system af...
# 18225             30.933  We are still working on our metering system. E...
# 18226             54.710  We are still working on our meter system. The ...
# 18227             80.533  We are still working on our water meter system...
# 18228            180.645  Due to the 2018 Camp Fire we are still without...
# 18229            200.258  We are still without a meter system.  Hope to ...
#
# [20 rows x 29 columns]

# %%
complete_data[
    (complete_data.supplier_name=="El Segundo City of")&
    (complete_data.reporting_month >= "2021-07-15") &
    (complete_data.reporting_month != "2021-08-15")
].groupby("supplier_name")[["total_gallons_current","total_gallons_baseline"]].sum().reset_index()
# Out:
#         supplier_name  total_gallons_current  total_gallons_baseline
# 0  El Segundo City of         3476540999.868          2817199764.284

# %%
( (3476540999.868-2817199764.284) / 16654) / 607
# Out:
# 65.22333272305075

# %%
chart_data = complete_data[complete_data.supplier_name == "Los Angeles Department of Water and Power"]
name = chart_data.iloc[0]["supplier_name"]

alt.Chart(
    chart_data
).mark_bar().encode(
    x=alt.X('yearmonth(reporting_month):T', axis=alt.Axis(title="Reporting month")),
    y=alt.Y("gallons_pct_change:Q", axis=alt.Axis(format="%", title="Percent change in gallons used")),
    color=alt.condition(
        alt.datum.gallons_pct_change > 0,
        alt.value("#e6ae56"),  # The positive color
        alt.value("#83c6e0")  # The negative color
    ),
    tooltip=["reporting_month","gallons_pct_change"]
).properties(title=f"Monthly water conservation in {name}", width=600)
# Out:
# alt.Chart(...)

# %%
alt.Chart(
    complete_data[complete_data.supplier_name.str.contains("El Segundo")]
).mark_bar().encode(
    x=alt.X('yearmonth(reporting_month):T'),
    y="total_gallons_current",
    tooltip=["reporting_month"]
).properties(width=600)
# Out:
# alt.Chart(...)

# %% [markdown]
# Drop districts for which we can't calculate a percentage change

# %%
drop_na_districts = district_cumulative_savings_df.dropna(subset="cumulative_pct_change")

# %% [markdown]
# By region

# %%
regions_cumulative_savings_df = district_cumulative_savings_df.groupby(
    ["hydrologic_region"]
)[
    ["total_gallons_current","total_gallons_baseline","supplier_name"]
].agg(
    {"total_gallons_current":"sum","total_gallons_baseline":"sum","supplier_name":"size"}
).reset_index().rename(
    columns={"supplier_name": "total_reports"}
)

# %%
regions_cumulative_savings_df = pd.merge(
    regions_cumulative_savings_df,
    pops_by_region[["hydrologic_region","total_population_served"]],
    how="left",
    on="hydrologic_region"
)

# %%
regions_cumulative_savings_df["cumulative_pct_change"] = regions_cumulative_savings_df.apply(lambda x: pct_change(x.total_gallons_current, x.total_gallons_baseline), axis=1)

# %%
regions_cumulative_savings_df['date'] = date

# %%
regions_cumulative_savings_df['months_since'] = months_since_reductions_begin
regions_cumulative_savings_df['days_since'] = days_since_reductions

# %%
regions_cumulative_savings_df['gallons_saved_per_month'] = regions_cumulative_savings_df.apply(
    lambda x: gallons_per_unit(
        x.total_gallons_current, x.total_gallons_baseline, x.total_population_served, x.months_since
    ), axis=1
)

# %%
regions_cumulative_savings_df['gallons_saved_per_day'] = regions_cumulative_savings_df.apply(
    lambda x: gallons_per_unit(
        x.total_gallons_current, x.total_gallons_baseline, x.total_population_served, x.days_since
    ), axis=1
)

# %%
regions_cumulative_savings_df
# Out:
#    hydrologic_region  total_gallons_current  total_gallons_baseline  \
# 0      Central Coast        73865571281.509         77922514628.424
# 1     Colorado River       108069739159.527        110652807284.326
# 2        North Coast        17913929375.749         21147007717.480
# 3     North Lahontan         5762871698.000          6347444088.000
# 4   Sacramento River       277510747649.635        301350744163.494
# 5  San Francisco Bay       366506427115.116        414252529720.338
# 6  San Joaquin River       140029015637.925        147748201736.937
# 7        South Coast      1427063906220.590       1513832634601.930
# 8     South Lahontan        64471209610.508         69254042032.883
# 9        Tulare Lake       210975670096.034        218920780615.957
#
#    total_reports  total_population_served  cumulative_pct_change       date  \
# 0             27                  1293270                 -0.052 2023-02-15
# 1             11                   780308                 -0.023 2023-02-15
# 2             11                   414740                 -0.153 2023-02-15
# 3              3                   103768                 -0.092 2023-02-15
# 4             38                  2843785                 -0.079 2023-02-15
# 5             39                  6671142                 -0.115 2023-02-15
# 6             19                  1706054                 -0.052 2023-02-15
# 7            147                 20450766                 -0.057 2023-02-15
# 8             13                   863361                 -0.069 2023-02-15
# 9             24                  1982976                 -0.036 2023-02-15
#
#    months_since  days_since  gallons_saved_per_month  gallons_saved_per_day
# 0            19         607                  165.103                  5.168
# 1            19         607                  174.227                  5.454
# 2            19         607                  410.286                 12.843
# 3            19         607                  296.498                  9.281
# 4            19         607                  441.221                 13.811
# 5            19         607                  376.690                 11.791
# 6            19         607                  238.136                  7.454
# 7            19         607                  223.306                  6.990
# 8            19         607                  291.568                  9.126
# 9            19         607                  210.877                  6.601

# %%
chart_data = regions_df[regions_df.hydrologic_region=="South Coast"]
name = chart_data.iloc[0]["hydrologic_region"]

alt.Chart(
    chart_data
).mark_bar().encode(
    x=alt.X('yearmonth(reporting_month):T'),
    y="gallons_pct_change:Q",
    color=alt.condition(
        alt.datum.gallons_pct_change > 0,
        alt.value("#e6ae56"),  # The positive color
        alt.value("#83c6e0")  # The negative color
    ),
    tooltip=["reporting_month","gallons_pct_change"]
).properties(title=f"Monthly water conservation in {name}", width=600)
# Out:
# alt.Chart(...)

# %% [markdown]
# Statewide

# %%
district_cumulative_savings_df["state"] = "California"

# %%
statewide_cumulative_savings_df = district_cumulative_savings_df.groupby(
    ["state"]
)[
    ["total_gallons_current","total_gallons_baseline", "supplier_name"]
].agg({
    "total_gallons_current": "sum",
    "total_gallons_baseline": "sum",
    "supplier_name": "size"
}).reset_index().rename(
    columns={"supplier_name": "total_reports"}
)

# %%
#statewide_cumulative_savings_df["total_reports"] = statewide_cumulative_savings_df["total_reports"]

# %%
statewide_cumulative_savings_df["total_population_served"] = pop_state

# %%
statewide_cumulative_savings_df["cumulative_pct_change"] = statewide_cumulative_savings_df.apply(lambda x: pct_change(x.total_gallons_current, x.total_gallons_baseline), axis=1)

# %%
statewide_cumulative_savings_df['date'] = date

# %%
statewide_cumulative_savings_df['months_since'] = months_since_reductions_begin
statewide_cumulative_savings_df['days_since'] = days_since_reductions

# %%
statewide_cumulative_savings_df['gallons_saved_per_month'] = regions_cumulative_savings_df.apply(
    lambda x: gallons_per_unit(
        x.total_gallons_current, x.total_gallons_baseline, x.total_population_served, x.months_since
    ), axis=1
)

# %%
statewide_cumulative_savings_df['gallons_saved_per_day'] = statewide_cumulative_savings_df.apply(
    lambda x: gallons_per_unit(
        x.total_gallons_current, x.total_gallons_baseline, x.total_population_served, x.days_since
    ), axis=1
)

# %%
statewide_cumulative_savings_df
# Out:
#         state  total_gallons_current  total_gallons_baseline  total_reports  \
# 0  California      2692169087844.593       2881428706589.769            332
#
#    total_population_served  cumulative_pct_change       date  months_since  \
# 0                 37110170                 -0.066 2023-02-15            19
#
#    days_since  gallons_saved_per_month  gallons_saved_per_day
# 0         607                  165.103                  8.402

# %%
alt.Chart(
    statewide_df
).mark_bar().encode(
    x=alt.X('yearmonth(reporting_month):T', axis=alt.Axis(title="Reporting month")),
    y=alt.Y("gallons_pct_change:Q", axis=alt.Axis(format="%", title="Percent change in gallons used")),
    color=alt.condition(
        alt.datum.gallons_pct_change > 0,
        alt.value("#e6ae56"),  # The positive color
        alt.value("#83c6e0")  # The negative color
    ),
    tooltip=["reporting_month","gallons_pct_change"]
).properties(title=f"Monthly water conservation in California", width=600)
# Out:
# alt.Chart(...)

# %% [markdown]
# ### Export
