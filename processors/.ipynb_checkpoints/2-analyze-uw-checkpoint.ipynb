# %%
import pandas as pd
import altair as alt
import altair_latimes as lat

# %%
alt.themes.register('latimes', lat.theme)
alt.themes.enable('latimes')
# Out:
# ThemeRegistry.enable('latimes')

# %% [markdown]
# ### Import

# %%
df = pd.read_csv("../data/raw/uw-usage.csv", parse_dates=["Reporting Month"])

# %% [markdown]
# ### Clean

# %%
df.columns = df.columns.str.replace(" ","_").str.replace("-","_").str.replace(r'[#,@,&,(,)]', '', regex=True).str.lower()

# %% [markdown]
# Trim this downn to just the columns we need

# %%
df.columns
# Out:
# Index(['supplier_name', 'public_water_system_id', 'reporting_month', 'county',
#        'hydrologic_region', 'climate_zone', 'total_population_served',
#        'reference_2014_population', 'county_under_drought_declaration',
#        'water_shortage_contingency_stage_invoked',
#        'water_shortage_level_indicator',
#        'dwr_state_standard_level_corresponding_to_stage',
#        'water_production_units',
#        'reported_preliminary_total_potable_water_production',
#        'reported_final_total_potable_water_production',
#        'preliminary_percent_residential_use', 'final_percent_residential_use',
#        'reported_preliminary_commercial_agricultural_water',
#        'reported_final_commercial_agricultural_water',
#        'reported_preliminary_commercial_industrial_and_institutional_water',
#        'reported_final_commercial_industrial_and_institutional_water',
#        'reported_recycled_water', 'reported_non_revenue_water',
#        'calculated_total_potable_water_production_gallons_ag_excluded',
#        'calculated_total_potable_water_production_gallons_2013_ag_excluded',
#        'calculated_commercial_agricultural_water_gallons',
#        'calculated_commercial_agricultural_water_gallons_2013',
#        'calculated_r_gpcd', 'qualification'],
#       dtype='object')

# %%
keeps = [
    'supplier_name', 
    'public_water_system_id', 
    'reporting_month', 
    'county',
    'hydrologic_region', 
    'climate_zone', 
    'total_population_served',
    # 'county_under_drought_declaration',
    # 'water_shortage_contingency_stage_invoked',
    # 'water_shortage_level_indicator',
    # 'dwr_state_standard_level_corresponding_to_stage',
    'water_production_units',
    'reported_preliminary_total_potable_water_production',
    'reported_final_total_potable_water_production',
    'preliminary_percent_residential_use', 
    'final_percent_residential_use',
    # 'reported_preliminary_commercial_agricultural_water',
    # 'reported_final_commercial_agricultural_water',
    # 'reported_preliminary_commercial,_industrial_and_institutional_water',
    # 'reported_final_commercial_industrial_and_institutional_water',
    # 'reported_recycled_water', 
    # 'reported_non_revenue_water',
    'calculated_total_potable_water_production_gallons_ag_excluded',
    # 'calculated_total_potable_water_production_gallons_2013_ag_excluded',
    # 'calculated_commercial_agricultural_water_gallons',
    # 'calculated_commercial_agricultural_water_gallons_2013',
    'calculated_r_gpcd', 
    # 'qualification'
]

# %%
trim_df = df[keeps]

# %%
trim_df.head()
# Out:
#                            supplier_name public_water_system_id  \
# 0  East Bay Municipal Utilities District              CA0110005
# 1  East Bay Municipal Utilities District              CA0110005
# 2  East Bay Municipal Utilities District              CA0110005
# 3  East Bay Municipal Utilities District              CA0110005
# 4  East Bay Municipal Utilities District              CA0110005
#
#   reporting_month                county  hydrologic_region  climate_zone  \
# 0      2022-03-15  Alameda,Contra Costa  San Francisco Bay             3
# 1      2022-02-15  Alameda,Contra Costa  San Francisco Bay             3
# 2      2022-01-15  Alameda,Contra Costa  San Francisco Bay             3
# 3      2021-12-15  Alameda,Contra Costa  San Francisco Bay             3
# 4      2021-11-15  Alameda,Contra Costa  San Francisco Bay             3
#
#    total_population_served water_production_units  \
# 0                  1430000                     MG
# 1                  1430000                     MG
# 2                  1420000                     MG
# 3                  1420000                     MG
# 4                  1420000                     MG
#
#    reported_preliminary_total_potable_water_production  \
# 0                                             4481.0
# 1                                             3898.0
# 2                                             3807.0
# 3                                             3754.0
# 4                                             3773.0
#
#    reported_final_total_potable_water_production  \
# 0                                            NaN
# 1                                            NaN
# 2                                            NaN
# 3                                            NaN
# 4                                            NaN
#
#    preliminary_percent_residential_use  final_percent_residential_use  \
# 0                                 58.0                            NaN
# 1                                 54.0                            NaN
# 2                                 58.0                            NaN
# 3                                 60.0                            NaN
# 4                                 61.0                            NaN
#
#    calculated_total_potable_water_production_gallons_ag_excluded  \
# 0                                       4.481000e+09
# 1                                       3.898000e+09
# 2                                       3.807000e+09
# 3                                       3.754000e+09
# 4                                       3.773000e+09
#
#    calculated_r_gpcd
# 0            58.6280
# 1            52.5704
# 2            50.1604
# 3            51.1677
# 4            54.0265

# %% [markdown]
# Calculate population-weighted r-gpcd for hydrologic regions

# %%
def regional_calcs(df, gals, rgpcd, pop):
    val = df[rgpcd]
    wt = df[pop]
    wt_avg = (val * wt).sum() / wt.sum()
    #return (val * wt).sum() / wt.sum()
    total_gals = df[gals].sum()
    total_pop = df[pop].sum()
    return pd.Series([total_pop, total_gals, wt_avg], index=['total_pop', 'total_gallons', 'pop_weighted_average'])

# %%
region_df = trim_df.groupby(
    ['reporting_month','hydrologic_region']
).apply(
    regional_calcs,
    "calculated_total_potable_water_production_gallons_ag_excluded",
    'calculated_r_gpcd', 
    'total_population_served'
).reset_index()

# %%
region_df
# Out:
#     reporting_month  hydrologic_region   total_pop  total_gallons  \
# 0        2014-06-15      Central Coast   1222138.0   5.604272e+09
# 1        2014-06-15     Colorado River    753033.0   7.206261e+09
# 2        2014-06-15        North Coast    372282.0   1.545991e+09
# 3        2014-06-15     North Lahontan     92882.0   6.701514e+08
# 4        2014-06-15   Sacramento River   2611811.0   2.190972e+10
# ..              ...                ...         ...            ...
# 935      2022-03-15  San Francisco Bay   6569288.0   1.858536e+10
# 936      2022-03-15  San Joaquin River   1536399.0   6.692555e+09
# 937      2022-03-15        South Coast  19795946.0   7.224709e+10
# 938      2022-03-15     South Lahontan    837117.0   3.205327e+09
# 939      2022-03-15        Tulare Lake   1933971.0   8.820643e+09
#
#      pop_weighted_average
# 0               99.958677
# 1              221.820762
# 2               88.473368
# 3              161.949192
# 4              186.962350
# ..                    ...
# 935             58.590408
# 936             92.508034
# 937             76.396130
# 938             90.109902
# 939             93.878934
#
# [940 rows x 5 columns]

# %%
statewide_df = trim_df.groupby(
    ['reporting_month']
).apply(
    regional_calcs,
    "calculated_total_potable_water_production_gallons_ag_excluded",
    'calculated_r_gpcd', 
    'total_population_served'
).reset_index()

# %%
# days_per_month = {
#     "1": 31,
#     "2": 28,
#     "3": 31,
#     "4": 30,
#     "5": 31,
#     "6": 30,
#     "7": 31,
#     "8": 31,
#     "9": 30,
#     "10": 31,
#     "11": 30,
#     "12": 31
# }

# %%
keeps = ['supplier_name', 'reporting_month', 'county',
       'hydrologic_region', 'total_population_served',
       #'county_under_drought_declaration',
       # 'water_shortage_contingency_stage_invoked',
       #'water_shortage_level_indicator',
         'dwr_state_standard_level_corresponding_to_stage',
        'calculated_r_gpcd']

# %%
trim_df = df[keeps]

# %%
merge_df = pd.merge(
    trim_df, 
    regional_usage[["hydrologic_region","reporting_month","pop_weighted_rgpcd"]], 
    how="left", 
    on=["hydrologic_region","reporting_month"]
)

# %%
melt = pd.melt(
    merge_df, 
    id_vars=["supplier_name","hydrologic_region","reporting_month"], 
    value_vars=["calculated_r_gpcd","pop_weighted_rgpcd"]
)

# %%
base = alt.Chart(
    merge_df[(merge_df.supplier_name == "Los Angeles Department of Water and Power") & (merge_df.reporting_month > "2021-04-01")]
).encode(
    x=alt.X("yearmonth(reporting_month):O"),
)

bar = base.mark_bar(color="#83c6e0").encode(
    y=alt.Y("calculated_r_gpcd", stack=None)
)

avg_line = base.mark_line(interpolate='step', color='#1281aa').encode(
    y=alt.Y("pop_weighted_rgpcd")
)

goal_line = alt.Chart(pd.DataFrame({'y': [80]})).mark_rule(color="#b75a36",strokeDash=[10,11]).encode(y='y')

(bar + avg_line + goal_line).properties(title="LADWP residential water usage compared to regional average", width=600)
# Out:
# alt.LayerChart(...)

# %%
merge_df#[(merge_df.supplier_name == "Los Angeles Department of Water and Power") & (merge_df.reporting_month > "2021-04-01")]
# Out:
#                                supplier_name reporting_month  \
# 0      East Bay Municipal Utilities District      2022-03-15
# 1      East Bay Municipal Utilities District      2022-02-15
# 2      East Bay Municipal Utilities District      2022-01-15
# 3      East Bay Municipal Utilities District      2021-12-15
# 4      East Bay Municipal Utilities District      2021-11-15
# ...                                      ...             ...
# 37103    Thermalito Water and Sewer District      2021-05-15
# 37104    Thermalito Water and Sewer District      2021-04-15
# 37105    Thermalito Water and Sewer District      2021-03-15
# 37106    Thermalito Water and Sewer District      2021-02-15
# 37107    Thermalito Water and Sewer District      2021-01-15
#
#                      county  hydrologic_region  total_population_served  \
# 0      Alameda,Contra Costa  San Francisco Bay                1430000.0
# 1      Alameda,Contra Costa  San Francisco Bay                1430000.0
# 2      Alameda,Contra Costa  San Francisco Bay                1420000.0
# 3      Alameda,Contra Costa  San Francisco Bay                1420000.0
# 4      Alameda,Contra Costa  San Francisco Bay                1420000.0
# ...                     ...                ...                      ...
# 37103                 Butte   Sacramento River                  10312.0
# 37104                 Butte   Sacramento River                  10312.0
# 37105                 Butte   Sacramento River                  10312.0
# 37106                 Butte   Sacramento River                  10312.0
# 37107                 Butte   Sacramento River                  10312.0
#
#        dwr_state_standard_level_corresponding_to_stage  calculated_r_gpcd  \
# 0                                                  5.0            58.6280
# 1                                                  NaN            52.5704
# 2                                                  NaN            50.1604
# 3                                                  NaN            51.1677
# 4                                                  NaN            54.0265
# ...                                                ...                ...
# 37103                                              NaN           228.7530
# 37104                                              NaN           148.1860
# 37105                                              NaN            89.5637
# 37106                                              NaN            86.9818
# 37107                                              NaN            89.3124
#
#        pop_weighted_rgpcd
# 0                      59
# 1                      55
# 2                      48
# 3                      48
# 4                      50
# ...                   ...
# 37103                 159
# 37104                 123
# 37105                  63
# 37106                  72
# 37107                  72
#
# [37108 rows x 8 columns]

# %%
sort_df = merge_df.sort_values(["reporting_month","supplier_name"])

# %%
sort_df.to_csv("../data/processed/district-level-residential-use.csv", index=False)
